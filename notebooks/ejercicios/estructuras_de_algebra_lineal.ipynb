# %%
import numpy as np

# %%
x = np.array([25, 2, -3, -23])
x.T
# Out:
# array([ 25,   2,  -3, -23])

# %% [markdown]
# Respuesta no tiene traspuesta

# %%
x = np.array([[25, 2, -3, -23]])
x.T
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %% [markdown]
# Aunque si es un array si que tiene traspuesta

# %%
x = np.array([[25], [2], [-3], [-23]])
x.T
# Out:
# array([[ 25,   2,  -3, -23]])

# %% [markdown]
# Y la traspuesta del vector columna es la fila

# %%
X = np.array([[42, 4, 7, 99], [-99, -3, 17, 22]])

X.shape
# Out:
# (2, 4)

# %% [markdown]
# Respuesta tiene 2 filas y 4 columnas (2,4)

# %%
X[1][2]
# Out:
# np.int64(17)

# %% [markdown]
# Respuesta en python la posicion es la 1,2 pero en notiacion normal esta en la fila 2 y en la columna 3. (2,3) y es el elemento X[2,3]
