# %%
import numpy as np

# %%
X = np.array([[25, 2], [3,4]])

np.linalg.det(X)
# Out:
# np.float64(94.0)

# %% [markdown]
# Tiene inversa

# %%
Y = np.array([[-2, 0], [0,-2]])

np.linalg.det(Y)
# Out:
# np.float64(4.0)

# %% [markdown]
# Tiene inversa

# %%
Z = np.array([[2, 1, -3], [4, -5, 2], [0, -1, 3]])

np.linalg.det(Z)
# Out:
# np.float64(-26.000000000000014)

# %% [markdown]
# Tiene inversa
