# %%
import numpy as np

# %%
Y = np.array([[42,4,7,99], [-99,-3, 17, 22]])
Y
# Out:
# array([[ 42,   4,   7,  99],
#        [-99,  -3,  17,  22]])

# %%
Y.T
# Out:
# array([[ 42, -99],
#        [  4,  -3],
#        [  7,  17],
#        [ 99,  22]])

# %%
X = np.array([[25, 10], [-2, 1]])
Y = np.array([[-1, 7], [10, 8]])


X * Y
# Out:
# array([[-25,  70],
#        [-20,   8]])

# %%
w = np.array([-1, 2, -2])
x = np.array([5 ,10, 0])

np.dot(w,x)
# Out:
# np.int64(15)
